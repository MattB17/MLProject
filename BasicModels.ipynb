# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC,LinearSVC
from sklearn.metrics import auc, roc_auc_score, mean_squared_error, r2_score, classification_report
from sklearn.ensemble import RandomForestClassifier

import os
import json

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Loading the data from files:

# %%
def construct_data_path(dataset_name):
    """Constructs the path to `dataset_name`.
    
    Parameters
    ----------
    dataset_name: str
        The name of the dataset.
    
    Returns
    -------
    str
        A path to the dataset.
    
    """
    return os.path.join('output_data', '{}.csv'.format(dataset_name))

# %%
train_data_1 = pd.read_csv(construct_data_path('interactions_training'))
validation_data_1 = pd.read_csv(construct_data_path('interactions_validation'))

# %%
train_data = train_data_1.copy()
validation_data = validation_data_1.copy()

# %%
train_data
# Out:
#                                  user_id  book_id  \
# 0       55e33e664f052f3858d8df5d9cd38597     2547
# 1       be813d0bb8f4cd8c4bd77870df3c8138     2696
# 2       695d92b05d837223608e5effcbefa14c    30119
# 3       841232985badbdc753f6179ab2dcf899    26596
# 4       08ff9ebbf8f94cf1d53b1fd87f077d6b   406373
# ...                                  ...      ...
# 228828  424fc2eb87fd7cd728c3a47bed12a21c    27822
# 228829  f0e04da6102375f3d85f7226c7e8f699     1466
# 228830  446a78a97c434dca98e7ea176ee9fa1f   958900
# 228831  e0b816dda8a16549dc52af5365b59fbe     1381
# 228832  43f0b15ad03605f67179aee00006bba3     3050
#
#                                review_id  is_read  rating  \
# 0       a3a8cf3cead1f647c240ce56d394090d     True       5
# 1       12774740d9a76a6dc5e2f60289358cf2     True       2
# 2       9cc215a3037c26944369c2b839c657fc     True       4
# 3       42b2bb4a3396fd2c63ee3fdba160fb03    False       0
# 4       0ee7eb8e9346ca6805f355fc9d8ad806     True       4
# ...                                  ...      ...     ...
# 228828  9ece538467c4803cbd54e0700cca43c9     True       5
# 228829  2b7ab730f5209f22ef7945cb633b852f    False       0
# 228830  69426bc6fc968e40bae7fdf37a9bd038    False       0
# 228831  b7de8df154aaab10eae62094c0e9b8d4    False       0
# 228832  15a0fa5215278001f943ad1aee887629    False       0
#
#        review_text_incomplete                      date_added  \
# 0                         NaN  Fri Oct 18 14:39:29 -0700 2013
# 1                         NaN  Tue Feb 07 01:27:13 -0800 2012
# 2                         NaN  Fri Apr 23 06:36:42 -0700 2010
# 3                         NaN  Thu Sep 25 23:17:27 -0700 2014
# 4                         NaN  Tue Sep 18 15:41:21 -0700 2007
# ...                       ...                             ...
# 228828                    NaN  Mon Feb 06 13:19:00 -0800 2012
# 228829                    NaN  Sat Jan 19 00:14:13 -0800 2013
# 228830                    NaN  Sat Jul 11 22:11:47 -0700 2015
# 228831                    NaN  Fri Jul 02 08:09:48 -0700 2010
# 228832                    NaN  Sun Sep 16 21:44:48 -0700 2012
#
#                           date_updated                         read_at  \
# 0       Fri Oct 18 14:39:29 -0700 2013                             NaN
# 1       Tue Feb 07 01:27:13 -0800 2012                             NaN
# 2       Fri Apr 23 06:36:42 -0700 2010                             NaN
# 3       Thu Sep 25 23:17:28 -0700 2014                             NaN
# 4       Wed Feb 13 07:23:38 -0800 2013                             NaN
# ...                                ...                             ...
# 228828  Tue Feb 21 14:07:48 -0800 2012  Wed Sep 28 00:00:00 -0700 2011
# 228829  Sat Jan 19 00:14:13 -0800 2013                             NaN
# 228830  Sat Jul 11 22:11:48 -0700 2015                             NaN
# 228831  Fri Jul 02 08:09:48 -0700 2010                             NaN
# 228832  Sun Sep 16 21:44:48 -0700 2012                             NaN
#
#        started_at        isbn  text_reviews_count      series country_code  \
# 0             NaN  000100039X                4280          []           US
# 1             NaN  0140424385                2071          []           US
# 2             NaN  0060513039                8950          []           US
# 3             NaN  0871401525                 181          []           US
# 4             NaN  0385031149                 421  ['471367']           US
# ...           ...         ...                 ...         ...          ...
# 228828        NaN  0192838997                 551          []           US
# 228829        NaN  1590171802                  54          []           US
# 228830        NaN  0918786169                  11          []           US
# 228831        NaN  0143039954                5608          []           US
# 228832        NaN         NaN                  29          []           US
#
#        language_code                                    popular_shelves asin  \
# 0                eng  [{'count': '1941', 'name': 'poetry'}, {'count'...  NaN
# 1                eng  [{'count': '3097', 'name': 'to-read'}, {'count...  NaN
# 2                eng  [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN
# 3                eng  [{'count': '22872', 'name': 'to-read'}, {'coun...  NaN
# 4                eng  [{'count': '425', 'name': 'fiction'}, {'count'...  NaN
# ...              ...                                                ...  ...
# 228828           eng  [{'count': '989', 'name': 'classics'}, {'count...  NaN
# 228829           eng  [{'count': '1304', 'name': 'to-read'}, {'count...  NaN
# 228830           eng  [{'count': '56', 'name': 'to-read'}, {'count':...  NaN
# 228831           eng  [{'count': '247044', 'name': 'to-read'}, {'cou...  NaN
# 228832           eng  [{'count': '11345', 'name': 'to-read'}, {'coun...  NaN
#
#         is_ebook  average_rating kindle_asin  \
# 0          False            4.23  B06XDHQFVY
# 1          False            3.48  B018HCIHXY
# 2          False            4.29         NaN
# 3          False            4.35         NaN
# 4          False            3.97  B00O4CVNHE
# ...          ...             ...         ...
# 228828     False            4.09  B006HCU4UG
# 228829     False            4.39         NaN
# 228830     False            4.54         NaN
# 228831     False            3.73  B004TPNMFM
# 228832     False            3.68         NaN
#
#                                             similar_books  \
# 0       ['67377', '29946', '700480', '72910', '14572',...
# 1       ['3049', '449589', '119079', '51799', '765427'...
# 2       ['488240', '420404', '407429', '10065', '83520...
# 3       ['142080', '72155', '133380', '367802', '56378...
# 4       ['505913', '1576915', '849912', '1470', '29376...
# ...                                                   ...
# 228828  ['197132', '626685', '97390', '196865', '82211...
# 228829  ['823612', '834694', '150272', '245162', '1502...
# 228830                                                 []
# 228831  ['12914', '904843', '235719', '279456', '1536'...
# 228832  ['449589', '119079', '820905', '672875', '1617...
#
#                                               description     format  \
# 0       Kahlil Gibran's masterpiece, The Prophet, is o...  Paperback
# 1       The procession that crosses Chaucer's pages is...  Paperback
# 2       Where the Sidewalk Ends turns forty! Celebrate...  Hardcover
# 3       At the time of his death in 1962, E. E. Cummin...  Hardcover
# 4       Goethe's Faust reworks the late medieval myth ...        NaN
# ...                                                   ...        ...
# 228828  Eugene Onegin is the master work of the poet w...  Paperback
# 228829  Writing with a pitch and heat that gets to the...  Hardcover
# 228830  Poetry. YOU is a collection of poetry by Frank...  Paperback
# 228831  Literature's grandest evocation of life's jour...  Paperback
# 228832  Sir Gawain and the Green Knight is a late 14th...        NaN
#
#                                                      link  \
# 0       https://www.goodreads.com/book/show/2547.The_P...
# 1       https://www.goodreads.com/book/show/2696.The_C...
# 2       https://www.goodreads.com/book/show/30119.Wher...
# 3       https://www.goodreads.com/book/show/26596.Comp...
# 4        https://www.goodreads.com/book/show/406373.Faust
# ...                                                   ...
# 228828  https://www.goodreads.com/book/show/27822.Euge...
# 228829  https://www.goodreads.com/book/show/1466.Grief...
# 228830     https://www.goodreads.com/book/show/958900.You
# 228831  https://www.goodreads.com/book/show/1381.The_O...
# 228832  https://www.goodreads.com/book/show/3050.Sir_G...
#
#                                                   authors  \
# 0                  [{'author_id': '6466154', 'role': ''}]
# 1       [{'author_id': '1838', 'role': ''}, {'author_i...
# 2                   [{'author_id': '435477', 'role': ''}]
# 3                    [{'author_id': '10547', 'role': ''}]
# 4       [{'author_id': '285217', 'role': ''}, {'author...
# ...                                                   ...
# 228828  [{'author_id': '16070', 'role': ''}, {'author_...
# 228829  [{'author_id': '973', 'role': ''}, {'author_id...
# 228830               [{'author_id': '52285', 'role': ''}]
# 228831  [{'author_id': '903', 'role': ''}, {'author_id...
# 228832  [{'author_id': '4699102', 'role': ''}, {'autho...
#
#                             publisher  num_pages  publication_day  \
# 0                           Rupa & Co      127.0              1.0
# 1                    Penguin Classics      504.0             30.0
# 2       Harpercollins Childrens Books      176.0              NaN
# 3                           Liveright     1136.0              NaN
# 4                                 NaN      503.0              NaN
# ...                               ...        ...              ...
# 228828        Oxford University Press      240.0             22.0
# 228829       New York Review of Books      312.0              1.0
# 228830                     Lost Roads       48.0              1.0
# 228831               Penguin Classics      541.0             30.0
# 228832                            NaN        NaN              NaN
#
#                isbn13  publication_month      edition_information  \
# 0       9780001000391                1.0                      NaN
# 1       9780140424386                1.0                      NaN
# 2       9780060513030               11.0                      NaN
# 3       9780871401526                NaN                      NaN
# 4       9780385031141                NaN                      NaN
# ...               ...                ...                      ...
# 228828  9780192838995               10.0  Oxford World's Classics
# 228829  9781590171806                8.0                      NaN
# 228830  9780918786166                2.0                      NaN
# 228831  9780143039952               11.0                      NaN
# 228832            NaN                NaN                      NaN
#
#         publication_year                                                url  \
# 0                 2010.0  https://www.goodreads.com/book/show/2547.The_P...
# 1                 2003.0  https://www.goodreads.com/book/show/2696.The_C...
# 2                 2002.0  https://www.goodreads.com/book/show/30119.Wher...
# 3                 1994.0  https://www.goodreads.com/book/show/26596.Comp...
# 4                    NaN   https://www.goodreads.com/book/show/406373.Faust
# ...                  ...                                                ...
# 228828            1998.0  https://www.goodreads.com/book/show/27822.Euge...
# 228829            2006.0  https://www.goodreads.com/book/show/1466.Grief...
# 228830            2008.0     https://www.goodreads.com/book/show/958900.You
# 228831            2006.0  https://www.goodreads.com/book/show/1381.The_O...
# 228832               NaN  https://www.goodreads.com/book/show/3050.Sir_G...
#
#                                                 image_url  ratings_count  \
# 0       https://images.gr-assets.com/books/1355046521m...         145579
# 1       https://images.gr-assets.com/books/1261208589m...         150099
# 2       https://images.gr-assets.com/books/1168052448m...        1029527
# 3       https://images.gr-assets.com/books/1355093052m...          18787
# 4       https://images.gr-assets.com/books/1320404568m...          16520
# ...                                                   ...            ...
# 228828  https://s.gr-assets.com/assets/nophoto/book/11...          34192
# 228829  https://s.gr-assets.com/assets/nophoto/book/11...            479
# 228830  https://images.gr-assets.com/books/1288324510m...             75
# 228831  https://images.gr-assets.com/books/1390173285m...         680823
# 228832  https://images.gr-assets.com/books/1425594583m...            690
#
#          work_id                                   title  \
# 0        2938937                             The Prophet
# 1         986234                    The Canterbury Tales
# 2          30518                 Where the Sidewalk Ends
# 3         175882               Complete Poems, 1904-1962
# 4       24158213                                   Faust
# ...          ...                                     ...
# 228828   1795311                           Eugene Onegin
# 228829   1221846  Grief Lessons: Four Plays by Euripides
# 228830    943810                              You: Poems
# 228831   3356006                             The Odyssey
# 228832   2954048         Sir Gawain and the Green Knight
#
#                           title_without_series  shelved  read  rated  \
# 0                                  The Prophet        1     1      1
# 1                         The Canterbury Tales        1     1      1
# 2                      Where the Sidewalk Ends        1     1      1
# 3                    Complete Poems, 1904-1962        1     0      0
# 4                                        Faust        1     1      1
# ...                                        ...      ...   ...    ...
# 228828                           Eugene Onegin        1     1      1
# 228829  Grief Lessons: Four Plays by Euripides        1     0      0
# 228830                              You: Poems        1     0      0
# 228831                             The Odyssey        1     0      0
# 228832         Sir Gawain and the Green Knight        1     0      0
#
#         recommended year_month_added year_month_updated pub_date  \
# 0                 1          2013-10            2013-10  2010-01
# 1                 0          2012-02            2012-02  2003-01
# 2                 1          2010-04            2010-04  2002-11
# 3                 0          2014-09            2014-09  1994-00
# 4                 1          2007-09            2013-02      -00
# ...             ...              ...                ...      ...
# 228828            1          2012-02            2012-02  1998-10
# 228829            0          2013-01            2013-01  2006-08
# 228830            0          2015-07            2015-07  2008-02
# 228831            0          2010-07            2010-07  2006-11
# 228832            0          2012-09            2012-09      -00
#
#         is_translated  main_author  is_in_series  series_length  \
# 0                   0    6466154.0             0              1
# 1                   0       1838.0             0              1
# 2                   0     435477.0             0              1
# 3                   0      10547.0             0              1
# 4                   0     285217.0             1              2
# ...               ...          ...           ...            ...
# 228828              0      16070.0             0              1
# 228829              0        973.0             0              1
# 228830              0      52285.0             0              1
# 228831              0        903.0             0              1
# 228832              0    4699102.0             0              1
#
#                                         title_description
# 0       The Prophet Kahlil Gibran's masterpiece, The P...
# 1       The Canterbury Tales The procession that cross...
# 2       Where the Sidewalk Ends Where the Sidewalk End...
# 3       Complete Poems, 1904-1962 At the time of his d...
# 4       Faust Goethe's Faust reworks the late medieval...
# ...                                                   ...
# 228828  Eugene Onegin Eugene Onegin is the master work...
# 228829  Grief Lessons: Four Plays by Euripides Writing...
# 228830  You: Poems Poetry. YOU is a collection of poet...
# 228831  The Odyssey Literature's grandest evocation of...
# 228832  Sir Gawain and the Green Knight Sir Gawain and...
#
# [228833 rows x 50 columns]

# %% [markdown]
# Step 2: Preprocess the data
#
#     -Remove extra columns
#     -Add Useful columns
#     -Clean the data

# %%
def remove_extra_columns(data):
    """remove extra columns.
    
    Parameters
    ----------
    data: DataFrame
        the dataset.
    
    Returns
    -------
    DataFrame
        a dataframe without the extra coloumns.
    
    """
        
    columns_to_keep = ['text_reviews_count', 'popular_shelves', 
                       'average_rating', 'format', 'publisher', 
                       'num_pages', 'publication_month', 'publication_year', 
                       'ratings_count', 'title', 'is_translated', 
                       'is_in_series', 'series_length', 'recommended',
                       ]
#                        'shelved', 'read', 'rated']
    
    return data[columns_to_keep]

# %%
def get_popular_values(data, column, count): 
    """finds the top `count` values in `column`.
    
    Parameters
    ----------
    data: DataFrame
        The dataset.
    
    column: str
        Name of the column to search.
        
    count: int
        Number of the popular values to find.
    
    Returns
    -------
    list
        a list of popular values.
    
    """
        
    all_values = data.groupby(data[column])[column].count().sort_values(ascending=False)
    popular_values = all_values[0:count]
    return list(popular_values.index)

# %%
def onehot_encode_column(data, column, popular_values):
    """changes the `columns` into a series of one-hot encoded columns. 
    The values that are not in the popular_values will be encoded in the 'other' category. 
    
    Parameters
    ----------
    data: DataFrame
        The dataset.
    
    column: str
        Name of the column to search.
        
    popular_values: list
        A list of the popular_values in the `column` that will be kept. 
    
    Returns
    -------
    DataFrame
        a dataframe with the one-hot encoded columns. 
    
    """
        
    data = data.copy()
    data.loc[~(data[column].isin(popular_values)), column] = 'other'
    data = data.join(pd.get_dummies(data[column], prefix=column))
    data = data.drop([column],axis=1, errors='ignore')    
    return data

# %%
def get_total_shelved_count(shelves_str):
    """Find the total number of shelves that a book is in.
    
    Parameters
    ----------
    str: shelves_str
        a json encoded dictionary contrining the shelving information.
    
    Returns
    -------
    int
        total number of shelves a book is in.
    
    """
    
    total = 0
    shelves_str = shelves_str.replace("\'", "\"")
    shelves_list = json.loads(shelves_str)
    for shelve in shelves_list:
        total += int(shelve['count'])
    return total

# %%
def get_title_len(row):
    """Get the length of the title of the book. 
    
    Parameters
    ----------
    DataFrame Row: row
        A row of DataFrame corresponding the the book 
    
    Returns
    -------
    int
        The length of the title. Returns 0 on failure 
    
    """
        
    try:
        return len(row['title'])
    except:
        return 0

# %%
def engineer_features(data, popular_formats, popular_publishers):
    """Removes the extra features and adds useful ones.  
    
    Parameters
    ----------
    DataFrame: data
        A DataFrame
        
    popular_formats: list
        A list of the popular 'formats' that will be kept. 
    
    popular_publishers: list
        A list of the popular 'publishers' that will be kept. 
        
    
    
    Returns
    -------
    DataFrame:
        A modified DataFrame with one-hot encoded format and publishers, 
        total number of shelved instances, length of the title of the book, 
        and 0-filled NaN values in numeric fields. 
        Also without extra columns and without non-numeric fields. 
    
    """
        
        
    data = data.copy()
    
    data = remove_extra_columns(data)

    data = onehot_encode_column(data, 'format', popular_formats)
    data = onehot_encode_column(data, 'publisher', popular_publishers)
    
    data['shelved_count'] = data.apply(lambda row: get_total_shelved_count(row['popular_shelves']), axis=1)
    data['title_len'] = data.apply(lambda row: get_title_len(row), axis=1)

    fillna_columns = ['publication_month','publication_year',
                      'text_reviews_count','average_rating',
                      'num_pages','ratings_count']
    data[fillna_columns] = data[fillna_columns].fillna(0)

        
    data = data.drop(['popular_shelves','title'],axis=1)
    
    return data

# %%
popular_formats = get_popular_values(train_data,'format', 5)
popular_publishers = get_popular_values(train_data, 'publisher', 5)

# %%
train_data = engineer_features(train_data, popular_formats, popular_publishers)
validation_data = engineer_features(validation_data, popular_formats, popular_publishers)

# %%
train_columns = train_data.columns.tolist()
validation_data = validation_data.reindex(columns=train_columns, fill_value=0)

X_train = train_data.drop('recommended', axis = 1)
y_train = train_data['recommended']

X_validation = validation_data.drop('recommended', axis = 1)
y_validation = validation_data['recommended']

# %%
X_train.sample(10)
# Out:
#         text_reviews_count  average_rating  num_pages  publication_month  \
# 200860                2222            4.34      176.0               10.0
# 158509                 221            4.52       48.0               11.0
# 221200                 451            4.23       88.0                8.0
# 42947                10403            4.23      204.0               11.0
# 137658                 139            3.87      404.0                8.0
# 52856                   76            4.25      156.0                4.0
# 65800                 5608            3.73      541.0               11.0
# 201827                  86            4.09      102.0                1.0
# 211041                  66            4.35      160.0                1.0
# 16569                 1094            4.37      821.0                8.0
#
#         publication_year  ratings_count  is_translated  is_in_series  \
# 200860            2002.0         304689              0             0
# 158509            2011.0           2321              0             0
# 221200            1955.0          39309              0             0
# 42947             2014.0          92450              0             0
# 137658            2004.0           3536              0             0
# 52856             2013.0            449              0             0
# 65800             2006.0         680823              0             0
# 201827            2011.0            868              0             0
# 211041            1994.0           5007              0             0
# 16569             1984.0         161550              0             0
#
#         series_length  format_Hardcover  format_Kindle Edition  \
# 200860              1                 1                      0
# 158509              1                 1                      0
# 221200              1                 0                      0
# 42947               1                 0                      0
# 137658              1                 0                      0
# 52856               1                 0                      0
# 65800               1                 0                      0
# 201827              1                 0                      0
# 211041              1                 0                      0
# 16569               1                 0                      0
#
#         format_Mass Market Paperback  format_Paperback  format_ebook  \
# 200860                             0                 0             0
# 158509                             0                 0             0
# 221200                             0                 1             0
# 42947                              0                 1             0
# 137658                             0                 1             0
# 52856                              0                 1             0
# 65800                              0                 1             0
# 201827                             0                 1             0
# 211041                             0                 1             0
# 16569                              0                 0             0
#
#         format_other  publisher_Cambridge University Press  \
# 200860             0                                     0
# 158509             0                                     0
# 221200             0                                     0
# 42947              0                                     0
# 137658             0                                     0
# 52856              0                                     0
# 65800              0                                     0
# 201827             0                                     0
# 211041             0                                     0
# 16569              1                                     0
#
#         publisher_Createspace  publisher_Harpercollins Childrens Books  \
# 200860                      0                                        1
# 158509                      0                                        0
# 221200                      0                                        0
# 42947                       1                                        0
# 137658                      0                                        0
# 52856                       0                                        0
# 65800                       0                                        0
# 201827                      0                                        0
# 211041                      0                                        0
# 16569                       0                                        0
#
#         publisher_Penguin Classics  publisher_Vintage  publisher_other  \
# 200860                           0                  0                0
# 158509                           0                  0                1
# 221200                           0                  0                1
# 42947                            0                  0                0
# 137658                           1                  0                0
# 52856                            0                  0                1
# 65800                            1                  0                0
# 201827                           0                  0                1
# 211041                           1                  0                0
# 16569                            0                  0                1
#
#         shelved_count  title_len
# 200860         115268         20
# 158509           8396          1
# 221200          11078         30
# 42947           19861         14
# 137658           7045         18
# 52856            2003         44
# 65800          296840         11
# 201827           1789         16
# 211041           4506         14
# 16569           10051         30

# %% [markdown]
# Step 3: Prediction

# %%
def predict_logistic_regression(X_test, X_train, y_train):
    """classify X_test entries with a logistic regression classifier 
    
    Parameters
    ----------
    DataFrame: X_test
        A DataFrame corresponding to the test data
        
    DataFrame: X_train
        A DataFrame corresponding to the train data
        
    list: y_train
        A list of categories corresponding to the Xs in the X_train
        
    
    
    Returns
    -------
    list: 
        A list of predicted categories corresponding the X_test
    
    """
        
    regr = LogisticRegression(max_iter = 10000)
    regr.fit(X_train, y_train)
    y_pred = regr.predict(X_test)
    
    return y_pred

# %%
y_pred_logistic_regression = predict_logistic_regression(X_validation, X_train, y_train)

# %%
print(classification_report(y_validation, y_pred_logistic_regression))
print(roc_auc_score(y_validation, y_pred_logistic_regression))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.69      0.61     22029
#            1       0.68      0.55      0.61     27007
#
#     accuracy                           0.61     49036
#    macro avg       0.62      0.62      0.61     49036
# weighted avg       0.63      0.61      0.61     49036
#
# 0.6186693690426348

# %%
def predict_svm(X_test, X_train, y_train):
    """classify X_test entries with a logistic a linear support vector classifier 
    
    Parameters
    ----------
    DataFrame: X_test
        A DataFrame corresponding to the test data
        
    DataFrame: X_train
        A DataFrame corresponding to the train data
        
    list: y_train
        A list of categories corresponding to the Xs in the X_train
        
    
    
    Returns
    -------
    list: 
        A list of predicted categories corresponding the X_test
    
    """
        
    
    clf = make_pipeline(StandardScaler(), 
                        LinearSVC(random_state=0, max_iter=10000))
    
    clf.fit(X_train, y_train)
    
    y_pred = clf.predict(X_test)
    
    return y_pred

# %%
y_pred_svm = predict_svm(X_validation,X_train[:50000],y_train[:50000])
# Out:
# /home/farid/miniconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
print(classification_report(y_validation, y_pred_svm))
print(roc_auc_score(y_validation, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.67      0.61     22029
#            1       0.68      0.57      0.62     27007
#
#     accuracy                           0.62     49036
#    macro avg       0.62      0.62      0.62     49036
# weighted avg       0.63      0.62      0.62     49036
#
# 0.6212982145613106

# %%
def predict_random_forest(X_test, X_train, y_train):
    """classify X_test entries with a Random Forest classifier 
    
    Parameters
    ----------
    DataFrame: X_test
        A DataFrame corresponding to the test data
        
    DataFrame: X_train
        A DataFrame corresponding to the train data
        
    list: y_train
        A list of categories corresponding to the Xs in the X_train
        
    
    
    Returns
    -------
    list: 
        A list of predicted categories corresponding the X_test
    
    """
        
    clf = RandomForestClassifier(n_estimators=400, max_depth=20, random_state=0)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return y_pred

# %%
y_pred_random_forest = predict_random_forest(X_validation,X_train,y_train)

# %%
print(classification_report(y_validation, y_pred_random_forest))
print(roc_auc_score(y_validation, y_pred_random_forest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61     22029
#            1       0.69      0.72      0.70     27007
#
#     accuracy                           0.66     49036
#    macro avg       0.66      0.66      0.66     49036
# weighted avg       0.66      0.66      0.66     49036
#
# 0.6579395800534599
