# %% [markdown]
# # Goodreads Exploratory Analysis
#
# Exploratory analysis of the goodreads datasets. This analysis is applied to the poetry books of the goodreads dataset.
#
# ### Imports

# %%
import json
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
plt.style.use('seaborn-darkgrid')
# %matplotlib inline

# %% [markdown]
# ### Loading data

# %%
def load_and_sample_dataset(data_path, sample_percentage):
    """Used to load `sample_percentage`% of the data at `data_path`.
    
    Parameters
    ----------
    data_path: str
        A string representing the path to the data
    sample_percentage: float
        A number between 0 and 100 representing the fraction
        of the data to sample.
    
    Returns
    -------
    pd.DataFrame
        A pandas dataframe object loaded from `data_path` after
        loading `sample_percentage`% of the data.
    
    """
    data = []
    idx = 0
    modulus = 100 // sample_percentage
    with open(data_path, 'r') as data_file:
        for row in data_file:
            if idx % modulus == 0:
                data.append(json.loads(row))
            idx += 1
    return pd.DataFrame(data)

# %%
def construct_data_path(dataset_name):
    """Constructs the path to `dataset_name`.
    
    Parameters
    ----------
    dataset_name: str
        The name of the dataset.
    
    Returns
    -------
    str
        A path to the dataset.
    
    """
    return os.path.join('data', '{}.json'.format(dataset_name))

# %%
interactions_df = load_and_sample_dataset(construct_data_path('goodreads_interactions_poetry'), 10)

# %%
books_df = load_and_sample_dataset(construct_data_path('goodreads_books_poetry'), 100)

# %%
reviews_df = load_and_sample_dataset(construct_data_path('goodreads_reviews_poetry'), 100)

# %% [markdown]
# ### Merging data

# %%
all_interactions_df = pd.merge(interactions_df, books_df, how='left', left_on="book_id", right_on="book_id")

# %%
pd.set_option('display.max_columns', None)

# %%
columns_to_keep = ['review_id', 'review_text', 'n_votes', 'n_comments']
new_cols = ['review_id', 'review_text', 'n_votes', 'n_comments']
reviews_df = reviews_df[columns_to_keep]
reviews_df.columns = new_cols
combined_df = pd.merge(all_interactions_df, reviews_df, how='left', left_on='review_id', right_on='review_id')
reviews_df = combined_df[~pd.isnull(combined_df['review_text'])]

# %%
non_reviews_df = all_interactions_df[~all_interactions_df.index.isin(reviews_df.index)]

# %%
len(non_reviews_df) + len(reviews_df) == len(all_interactions_df)
# Out:
# True

# %%
all_interactions_df.describe()
# Out:
#               rating
# count  273435.000000
# mean        1.826763
# std         2.122692
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         4.000000
# max         5.000000

# %%
positive_ratings = all_interactions_df[all_interactions_df['rating'] > 0]
positive_ratings.describe()
# Out:
#               rating
# count  123098.000000
# mean        4.057751
# std         0.977685
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000

# %%
reviews_df = reviews_df[reviews_df['rating'] > 0]
reviews_df.describe()
# Out:
#              rating       n_votes    n_comments
# count  14798.000000  14798.000000  14798.000000
# mean       3.990742      1.558657      0.257129
# std        1.041990      6.293236      1.653555
# min        1.000000     -1.000000      0.000000
# 25%        3.000000      0.000000      0.000000
# 50%        4.000000      0.000000      0.000000
# 75%        5.000000      1.000000      0.000000
# max        5.000000    259.000000     76.000000

# %%
non_reviews_df = non_reviews_df[non_reviews_df['rating'] > 0]
non_reviews_df.describe()
# Out:
#               rating
# count  108300.000000
# mean        4.066907
# std         0.968212
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000

# %%
master_df = all_interactions_df

# %%
rated_df = master_df[master_df['rating'] > 0]

# %% [markdown]
# It is definitely clear that ratings are biased upwards when a review is present
#
# ### Date Formatting and Visualization

# %%
def format_publication_date(data_df):
    """Formats the publication date in `data_df`.
    
    The formatted publication date has the form 'yyyy-mm'.
    
    Parameters
    ----------
    data_df: pd.DataFrame
        The pandas DataFrame for which the publication date will be formatted.
    
    Returns
    -------
    pd.DataFrame
        The pandas DataFrame obtained from `data_df` after adding a column
        for the formatted publication date.
    
    """
    data_df['formatted_pub_month'] = data_df['publication_month'].apply(lambda x: str(x).zfill(2))
    data_df['formatted_pub_year'] = data_df['publication_year'].apply(lambda x: str(x))
    data_df['pub_date'] = data_df['formatted_pub_year'] + "-" + data_df['formatted_pub_month']
    data_df = data_df.drop(columns=['formatted_pub_year', 'formatted_pub_month'])
    return data_df

# %%
month_map = {'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05', 'Jun': '06',
             'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12'}

def reformat_date_cols(data_df, date_cols):
    """Reformats date columns in `data_df` for easier analysis.
    
    The columns in `date_cols` are formatted in a way that is
    easier to visualize. The reformatted date columns have the
    format 'yyyy-mm'
    
    Parameters
    ----------
    data_df: pd.DataFrame
        A pandas DataFrame to which date columns will be added.
    date_cols: collection
        A collection of date columns to be reformatted
    
    Returns
    -------
    pd.DataFrame
        A pandas DataFrame obtained from `data_df` by augmenting it with
        reformatted date columns for the columns in `date_cols`.
    
    """
    for date_col in date_cols:
        col_name = date_col.split("_")[1]
        month_name = "month_{}".format(col_name)
        year_name = "year_{}".format(col_name)
        data_df[month_name] = data_df[date_col].apply(lambda x: month_map[x.split()[1]])
        data_df[year_name] = data_df[date_col].apply(lambda x: x.split()[-1])
        data_df['year_month_{}'.format(col_name)] = data_df[year_name] + "-" + data_df[month_name]
        data_df = data_df.drop(columns=[month_name, year_name])
    return data_df

# %%
def format_date_cols(data_df):
    """Formats the date columns of `data_df`.
    
    Parameters
    ----------
    data_df: pd.DataFrame
        The pandas DataFrame to be formatted.
    
    Returns
    -------
    pd.DataFrame
        The DataFrame obtained from `data_df` after
        formatting its columns.
    
    """
    data_df = reformat_date_cols(data_df, ['date_added', 'date_updated'])
    return format_publication_date(data_df)

# %%
books_df = format_publication_date(books_df)
rated_df = format_date_cols(rated_df)
reviews_df = format_date_cols(reviews_df)
non_reviews_df = format_date_cols(non_reviews_df)
# Out:
# <ipython-input-19-febda3f22134>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df[month_name] = data_df[date_col].apply(lambda x: month_map[x.split()[1]])
# <ipython-input-19-febda3f22134>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df[year_name] = data_df[date_col].apply(lambda x: x.split()[-1])
# <ipython-input-19-febda3f22134>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['year_month_{}'.format(col_name)] = data_df[year_name] + "-" + data_df[month_name]

# %%
def visualize_mean_rating_by_month(data_df, month_col, color='red'):
    """Visualizes the average rating in `data_df` by `month_col`.
    
    Parameters
    ----------
    data_df: pd.DataFrame
        The pandas dataframe containing the data to be visualized.
    month_col: str
        The name of the column in `data_df` over which the average
        rating will be visualized.
    color: str
        The color used to show the plot. The default is "red"
    
    Returns
    -------
    None
    
    """
    grouped_date = data_df.groupby(data_df[month_col])['rating'].mean()
    tick_labels = [x if x[-2:] == '06' else '' for x in grouped_date.index]
    
    plt.figure(figsize=(20,5))
    grouped_date.plot(color=color, linewidth=3)
    plt.xticks(range(len(tick_labels)), tick_labels)
    plt.ylim(0, 5)
    plt.show()

# %% [markdown]
# ### Rating by Date Added
#
# Visualizing average rating by date added across the 3 datasets

# %%
visualize_mean_rating_by_month(rated_df, 'year_month_added')

# %%
visualize_mean_rating_by_month(reviews_df, 'year_month_added')

# %%
visualize_mean_rating_by_month(non_reviews_df, 'year_month_added')

# %% [markdown]
# ### Rating by Date Updated
#
# Visualizing average rating by date updated across the 3 datasets

# %%
visualize_mean_rating_by_month(rated_df, 'year_month_updated', color='blue')

# %%
visualize_mean_rating_by_month(reviews_df, 'year_month_updated', color='blue')

# %%
visualize_mean_rating_by_month(non_reviews_df, 'year_month_updated', color='blue')

# %% [markdown]
# ### Rating by Publication Date
#
# Visualizing average rating by publication date across the 3 datasets

# %%
from scipy.signal import savgol_filter

def visualize_count_by_pub_date(data_df):
    
    grouped_count = data_df.groupby(data_df['pub_date'])['rating'].count()
    grouped_count[0]= 0
    tick_labels = [x if x[-4:] == '5-06' else '' for x in grouped_count.index]
    
    yhat = savgol_filter(grouped_count,499, 5)
    
    plt.figure(figsize=(20,10))
    grouped_count.plot(color='orange', linewidth=3)
    plt.plot(yhat, color='blue')
    plt.xticks(range(len(tick_labels)), tick_labels)
    plt.ylim(0, 800)
    plt.show()

# %%
visualize_count_by_pub_date(rated_df)

# %%
def visualize_mean_rating_by_pub_date(data_df):
    """Visualizes the average rating in `data_df` by publication date.
    
    Parameters
    ----------
    data_df: pd.DataFrame
        The pandas dataframe containing the data to be visualized.
    
    Returns
    -------
    None
    
    """
    grouped_date = data_df.groupby(data_df['pub_date'])['rating'].mean()
    tick_labels = [x if x[-4:] == '5-06' else '' for x in grouped_date.index]
    
    plt.figure(figsize=(20,5))
    grouped_date.plot(color='orange', linewidth=3)
    plt.xticks(range(len(tick_labels)), tick_labels)
    plt.ylim(0, 5)
    plt.show()

# %%
visualize_mean_rating_by_pub_date(rated_df)

# %%
visualize_mean_rating_by_pub_date(reviews_df)

# %%
visualize_mean_rating_by_pub_date(non_reviews_df)

# %% [markdown]
# Already it is evident that rating differ depending on whether the user left a review or not.
#
# Looking at average rating based on whether the user read the book

# %%
rated_df.groupby(rated_df['is_read'])['rating'].mean()
# Out:
# is_read
# True    4.057751
# Name: rating, dtype: float64

# %%
rated_df[rated_df['is_read'] == False]['rating'].unique()
# Out:
# array([], dtype=int64)

# %% [markdown]
# Confirms the intuition in the [Monotonic Behaviour Chains](http://cseweb.ucsd.edu/~jmcauley/pdfs/recsys18b.pdf) paper that users do not rate unless they have read first
#
# Looking at the various stages in the interactions dataset

# %%
def construct_counts_df(data_df):
    """Counts the number of interactions at various stages.
    
    That is, it counts the number of records in `data_df` at
    the different stages of shelved, read, rated, reviewed.
    
    Parameters
    ----------
    data_df: pd.DataFrame
        The DataFrame for which the counts are calculated.
    
    Returns
    -------
    pd.DataFrame
        A DataFrame containing counts for each stage.
    
    """
    shelved = len(data_df)
    read = len(data_df[data_df['is_read'] == True])
    rated = len(data_df[data_df['rating'] > 0])
    recommended = len(data_df[data_df['rating'] > 3])
    counts_df = pd.DataFrame([shelved, read, rated, recommended], index=['shelved', 'read', 'rated', 'recommended'], columns=['count'])
    counts_df['percent'] = counts_df['count'] / shelved
    counts_df['percent'] = counts_df['percent'].apply(lambda x: "{}%".format(round(x*100, 2)))
    return counts_df

# %%
construct_counts_df(master_df)
# Out:
#               count percent
# shelved      273435  100.0%
# read         131552  48.11%
# rated        123098  45.02%
# recommended   90660  33.16%

# %% [markdown]
# Looking at ratings across different books

# %%
grouped_books = rated_df.groupby(rated_df['book_id'])['rating'].mean()

# %%
rated_df['ratings_count'] = rated_df['ratings_count'].apply(lambda x: int(x))
rating_counts = rated_df.groupby(rated_df['book_id'])['ratings_count'].min()

# %%
rating_counts = rating_counts[rating_counts > 0].sort_values()
least_rated = rating_counts[:500].index
most_rated = rating_counts[-500:].index

books_least_rated = grouped_books[grouped_books.index.isin(least_rated)]
books_most_rated = grouped_books[grouped_books.index.isin(most_rated)]

# %%
def visualize_grouped_ratings(grouped_ratings, color='green'):
    """Creates a visual of the ratings in `grouped_ratings`.
    
    Assumes `grouped_ratings` is sorted in ascending order of the
    number of ratings. Thegroups could be books or users. And records
    at the start of the list correspond to groups that have fewer
    associated ratings.
    
    Parameters
    ----------
    grouped_ratings: np.array
        An numpy array of average ratings by group.
    color: str
        The color used for the line in the plot. The
        default is 'green'
    
    Returns
    -------
    None
    
    """
    tick_labels = [str(i) if i % 20 == 10 else '' for i in range(len(grouped_ratings))]
    
    plt.figure(figsize=(20,5))
    grouped_ratings.plot(color=color, linewidth=3)
    plt.xticks(range(len(grouped_ratings)), tick_labels)
    plt.ylim(0, 5)
    plt.show()

# %%
visualize_grouped_ratings(books_least_rated)

# %%
visualize_grouped_ratings(books_most_rated)

# %% [markdown]
# There seems to be no real pattern for the least rated books. However, for the most rated books the ratings seem to almost always be 3 or higher

# %% [markdown]
# Looking at ratings across different users

# %%
grouped_users = rated_df.groupby(rated_df['user_id'])['rating'].mean()

# %%
grouped_user_count = rated_df.groupby(rated_df['user_id'])['rating'].count()
grouped_user_count = grouped_user_count.sort_values()

infrequent_raters = grouped_user_count[:500].index
frequent_raters = grouped_user_count[-500:].index

infrequent_rater_ratings = grouped_users[grouped_users.index.isin(infrequent_raters)]
frequent_rater_ratings = grouped_users[grouped_users.index.isin(frequent_raters)]

# %%
visualize_grouped_ratings(infrequent_rater_ratings)

# %%
visualize_grouped_ratings(frequent_rater_ratings)

# %% [markdown]
# This is the same story as for books. Although it seems that there is more variance in average rating for the frequent raters as opposed to the average rating for frequently rated results

# %% [markdown]
# Distribution of ratings:

# %%
plt.bar(range(1,6), rated_df.groupby('rating')['rating'].count())
plt.show()

# %%
language_counts = rated_df.groupby('language_code')['language_code'].count().sort_values()
common_languages = language_counts[language_counts > 500].index
common_languages_ratings = rated_df[rated_df['language_code'].isin(common_languages)].copy()
common_languages_ratings = common_languages_ratings[common_languages_ratings['language_code'] != '']

# %%
common_languages_ratings['average_rating'] = common_languages_ratings['average_rating'].apply(pd.to_numeric)
avg_rating_per_lang = common_languages_ratings[['language_code','average_rating']].groupby('language_code').agg('mean')['average_rating'].sort_values()
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(avg_rating_per_lang.index,avg_rating_per_lang, linewidth=3)
plt.ylim([3.7,4.3])
plt.show()

# %%
popular_shelves = pd.DataFrame(rated_df.popular_shelves.tolist())

# %%
popular_shelves.sample(3)
# Out:
#                                            0   \
# 23557     {'count': '572', 'name': 'to-read'}
# 111905    {'count': '702', 'name': 'to-read'}
# 3769    {'count': '11816', 'name': 'to-read'}
#
#                                                    1   \
# 23557   {'count': '127', 'name': 'currently-reading'}
# 111905             {'count': '163', 'name': 'poetry'}
# 3769              {'count': '1243', 'name': 'poetry'}
#
#                                                    2   \
# 23557            {'count': '57', 'name': 'favorites'}
# 111905   {'count': '11', 'name': 'currently-reading'}
# 3769    {'count': '275', 'name': 'currently-reading'}
#
#                                            3   \
# 23557      {'count': '50', 'name': 'spanish'}
# 111905    {'count': '8', 'name': 'favorites'}
# 3769    {'count': '187', 'name': 'favorites'}
#
#                                          4   \
# 23557   {'count': '48', 'name': 'classics'}
# 111905   {'count': '6', 'name': 'canadian'}
# 3769    {'count': '54', 'name': 'classics'}
#
#                                        5   \
# 23557   {'count': '47', 'name': 'poetry'}
# 111905  {'count': '5', 'name': 'fiction'}
# 3769    {'count': '50', 'name': 'german'}
#
#                                                6   \
# 23557           {'count': '34', 'name': 'poesía'}
# 111905  {'count': '4', 'name': 'margaret-atwood'}
# 3769        {'count': '29', 'name': 'literature'}
#
#                                         7   \
# 23557    {'count': '34', 'name': 'poesia'}
# 111905    {'count': '4', 'name': 'atwood'}
# 3769    {'count': '23', 'name': 'fiction'}
#
#                                                    8   \
# 23557   {'count': '21', 'name': 'spanish-literature'}
# 111905          {'count': '4', 'name': 'books-i-own'}
# 3769           {'count': '21', 'name': 'books-i-own'}
#
#                                            9   \
# 23557        {'count': '18', 'name': 'spain'}
# 111905  {'count': '3', 'name': 'owned-books'}
# 3769         {'count': '21', 'name': 'owned'}
#
#                                                   10  \
# 23557               {'count': '13', 'name': 'owned'}
# 111905              {'count': '3', 'name': 'canada'}
# 3769    {'count': '15', 'name': 'german-literature'}
#
#                                        11                                 12  \
# 23557      {'count': '12', 'name': 'شعر'}  {'count': '10', 'name': 'españa'}
# 111905    {'count': '3', 'name': 'owned'}   {'count': '3', 'name': 'canlit'}
# 3769    {'count': '15', 'name': 'to-buy'}   {'count': '14', 'name': 'poems'}
#
#                                                13  \
# 23557          {'count': '10', 'name': 'default'}
# 111905    {'count': '3', 'name': 'female-author'}
# 3769    {'count': '11', 'name': 'to-read-poetry'}
#
#                                                    14  \
# 23557         {'count': '10', 'name': '20th-century'}
# 111905  {'count': '3', 'name': 'canadian-literature'}
# 3769            {'count': '11', 'name': 'philosophy'}
#
#                                             15  \
# 23557       {'count': '10', 'name': 'fiction'}
# 111905      {'count': '3', 'name': 'feminism'}
# 3769    {'count': '10', 'name': 'non-fiction'}
#
#                                          16  \
# 23557    {'count': '10', 'name': 'español'}
# 111905    {'count': '2', 'name': 'default'}
# 3769    {'count': '9', 'name': 'wish-list'}
#
#                                            17  \
# 23557   {'count': '9', 'name': 'spanish-lit'}
# 111905   {'count': '2', 'name': 'literature'}
# 3769        {'count': '9', 'name': 'germany'}
#
#                                           18  \
# 23557   {'count': '9', 'name': 'literature'}
# 111905      {'count': '2', 'name': 'unread'}
# 3769         {'count': '9', 'name': 'rilke'}
#
#                                           19  \
# 23557      {'count': '7', 'name': 'classic'}
# 111905      {'count': '2', 'name': 'to-buy'}
# 3769    {'count': '8', 'name': 'favourites'}
#
#                                                        20  \
# 23557   {'count': '7', 'name': '100-best-books-of-all-...
# 111905              {'count': '2', 'name': 'read-poetry'}
# 3769                    {'count': '8', 'name': 'deutsch'}
#
#                                           21  \
# 23557   {'count': '7', 'name': 'favourites'}
# 111905       {'count': '2', 'name': 'poems'}
# 3769       {'count': '8', 'name': 'library'}
#
#                                                    22  \
# 23557   {'count': '6', 'name': 'literatura-española'}
# 111905          {'count': '1', 'name': 'recommended'}
# 3769           {'count': '8', 'name': '20th-century'}
#
#                                                        23  \
# 23557   {'count': '5', 'name': 'bokklubben-world-libra...
# 111905               {'count': '1', 'name': '2018-bingo'}
# 3769                 {'count': '7', 'name': 'translated'}
#
#                                                 24  \
# 23557   {'count': '5', 'name': 'guardian-top-100'}
# 111905    {'count': '1', 'name': 'to-read-poetry'}
# 3769        {'count': '7', 'name': 'spirituality'}
#
#                                                        25  \
# 23557       {'count': '5', 'name': 'literatura-espanola'}
# 111905  {'count': '1', 'name': 'univ-buffalo-48-good-b...
# 3769                 {'count': '7', 'name': 'nonfiction'}
#
#                                          26  \
# 23557      {'count': '5', 'name': 'poésie'}
# 111905  {'count': '1', 'name': 'school-hs'}
# 3769        {'count': '7', 'name': 'czech'}
#
#                                               27  \
# 23557         {'count': '5', 'name': 'clasicos'}
# 111905    {'count': '1', 'name': 'i-really-own'}
# 3769    {'count': '7', 'name': 'in-translation'}
#
#                                             28  \
# 23557     {'count': '4', 'name': 'en-español'}
# 111905      {'count': '1', 'name': '2018-tbr'}
# 3769    {'count': '7', 'name': 'translations'}
#
#                                                  29  \
# 23557      {'count': '4', 'name': '100-best-books'}
# 111905  {'count': '1', 'name': 'purchased-to-read'}
# 3769              {'count': '7', 'name': 'classic'}
#
#                                              30  \
# 23557          {'count': '4', 'name': 'to-buy'}
# 111905  {'count': '1', 'name': 'owned-to-read'}
# 3769       {'count': '7', 'name': 'my-library'}
#
#                                                        31  \
# 23557   {'count': '4', 'name': '100-best-books-of-all-...
# 111905                {'count': '1', 'name': '1001-1050'}
# 3769             {'count': '6', 'name': 'poetry-to-read'}
#
#                                               32  \
# 23557           {'count': '4', 'name': 'europe'}
# 111905  {'count': '1', 'name': 'a-open-library'}
# 3769            {'count': '5', 'name': '5-star'}
#
#                                           33  \
# 23557   {'count': '4', 'name': 'castellano'}
# 111905   {'count': '1', 'name': 'pub-1980s'}
# 3769       {'count': '5', 'name': 'default'}
#
#                                             34  \
# 23557     {'count': '4', 'name': 'in-spanish'}
# 111905  {'count': '1', 'name': 'fave-authors'}
# 3769     {'count': '5', 'name': 'translation'}
#
#                                                    35  \
# 23557                {'count': '4', 'name': 'poes-a'}
# 111905     {'count': '1', 'name': 'read-a-1401-1500'}
# 3769    {'count': '5', 'name': 'european-literature'}
#
#                                                36  \
# 23557   {'count': '4', 'name': 'read-in-spanish'}
# 111905   {'count': '1', 'name': 'greatest-books'}
# 3769         {'count': '5', 'name': 'german-lit'}
#
#                                                   37  \
# 23557       {'count': '3', 'name': 'to-read-poetry'}
# 111905          {'count': '1', 'name': '2016-books'}
# 3769    {'count': '5', 'name': 'all-time-favorites'}
#
#                                                        38  \
# 23557                 {'count': '3', 'name': 'wish-list'}
# 111905  {'count': '1', 'name': 'literature-12-reading-...
# 3769               {'count': '4', 'name': 'home-library'}
#
#                                            39  \
# 23557   {'count': '3', 'name': 'books-i-own'}
# 111905     {'count': '1', 'name': 'a-sell-3'}
# 3769       {'count': '4', 'name': 'religion'}
#
#                                               40  \
# 23557         {'count': '3', 'name': 'hispanic'}
# 111905           {'count': '1', 'name': 'adult'}
# 3769    {'count': '4', 'name': 'partially-read'}
#
#                                                   41  \
# 23557              {'count': '3', 'name': 'poezija'}
# 111905  {'count': '1', 'name': 'want-to-buy-borrow'}
# 3769              {'count': '4', 'name': 'my-books'}
#
#                                                 42  \
# 23557   {'count': '3', 'name': 'libros-que-tengo'}
# 111905      {'count': '1', 'name': 'updated-2016'}
# 3769         {'count': '4', 'name': 'owned-books'}
#
#                                                        43  \
# 23557         {'count': '3', 'name': 'world-library-100'}
# 111905  {'count': '1', 'name': 'summer-reading-list-20...
# 3769               {'count': '4', 'name': 'genre-poetry'}
#
#                                                        44  \
# 23557              {'count': '3', 'name': 'lit-española'}
# 111905  {'count': '1', 'name': 'own-but-haven-t-read-y...
# 3769               {'count': '4', 'name': 'poetry-drama'}
#
#                                                        45  \
# 23557                {'count': '3', 'name': 'biblioteca'}
# 111905  {'count': '1', 'name': 'anthologies-collections'}
# 3769                      {'count': '4', 'name': 'poesy'}
#
#                                                  46  \
# 23557               {'count': '3', 'name': 'i-own'}
# 111905  {'count': '1', 'name': 'social-commentary'}
# 3769                 {'count': '4', 'name': 'poem'}
#
#                                                  47  \
# 23557             {'count': '3', 'name': 'library'}
# 111905  {'count': '1', 'name': 'abandoned-for-now'}
# 3769          {'count': '4', 'name': 'partly-read'}
#
#                                                48  \
# 23557      {'count': '3', 'name': '100-le-monde'}
# 111905            {'count': '1', 'name': 'verse'}
# 3769    {'count': '4', 'name': 'favorite-poetry'}
#
#                                                   49  \
# 23557             {'count': '3', 'name': 'my-books'}
# 111905        {'count': '1', 'name': 'books-i-want'}
# 3769    {'count': '4', 'name': 'rainer-maria-rilke'}
#
#                                         50  \
# 23557   {'count': '3', 'name': 'clásicos'}
# 111905        {'count': '1', 'name': 'n2'}
# 3769      {'count': '3', 'name': 'poesie'}
#
#                                                  51  \
# 23557       {'count': '3', 'name': 'poesia-poetry'}
# 111905   {'count': '1', 'name': 'booktube-choices'}
# 3769    {'count': '3', 'name': 'shelfari-wishlist'}
#
#                                                   52  \
# 23557              {'count': '3', 'name': 'top-100'}
# 111905  {'count': '1', 'name': 'shelfari-favorites'}
# 3769              {'count': '3', 'name': 'favorite'}
#
#                                                 53  \
# 23557              {'count': '3', 'name': 'lorca'}
# 111905  {'count': '1', 'name': 'read-harder-2015'}
# 3769               {'count': '3', 'name': 'ebook'}
#
#                                              54  \
# 23557       {'count': '2', 'name': 'read-2017'}
# 111905  {'count': '1', 'name': '2-to-read-med'}
# 3769           {'count': '3', 'name': 'poésie'}
#
#                                              55  \
# 23557           {'count': '2', 'name': 'مترجم'}
# 111905            {'count': '1', 'name': 'fbg'}
# 3769    {'count': '3', 'name': 'german-poetry'}
#
#                                            56  \
# 23557           {'count': '2', 'name': 'fav'}
# 111905    {'count': '1', 'name': 'summer-15'}
# 3769    {'count': '3', 'name': 'recommended'}
#
#                                                 57  \
# 23557   {'count': '2', 'name': 'spanish-language'}
# 111905            {'count': '1', 'name': 'fab-15'}
# 3769           {'count': '3', 'name': 'bookshelf'}
#
#                                                        58  \
# 23557   {'count': '2', 'name': 'lugar-rio-guadalquivir...
# 111905                  {'count': '1', 'name': 're-read'}
# 3769                   {'count': '3', 'name': 'language'}
#
#                                                      59  \
# 23557                  {'count': '2', 'name': 'lírica'}
# 111905          {'count': '1', 'name': 'bedside-table'}
# 3769    {'count': '3', 'name': 'poetry-in-translation'}
#
#                                                 60  \
# 23557   {'count': '2', 'name': 'books-in-spanish'}
# 111905     {'count': '1', 'name': 'women-writers'}
# 3769               {'count': '3', 'name': 'adult'}
#
#                                                        61  \
# 23557                   {'count': '2', 'name': '3-stars'}
# 111905  {'count': '1', 'name': 'female-authors-book-cl...
# 3769               {'count': '3', 'name': 'poetry-prose'}
#
#                                                       62  \
# 23557       {'count': '2', 'name': '100-greatest-books'}
# 111905  {'count': '1', 'name': 'fairy-tales-and-poetry'}
# 3769                 {'count': '3', 'name': 'favourite'}
#
#                                               63  \
# 23557        {'count': '2', 'name': 'أدب-مترجم'}
# 111905          {'count': '1', 'name': 'theory'}
# 3769    {'count': '3', 'name': 'read-in-german'}
#
#                                                 64  \
# 23557             {'count': '2', 'name': 'spaans'}
# 111905               {'count': '1', 'name': 'old'}
# 3769    {'count': '3', 'name': 'personal-library'}
#
#                                                  65  \
# 23557   {'count': '2', 'name': 'سلسلة-المائة-كتاب'}
# 111905   {'count': '1', 'name': 'before-goodreads'}
# 3769             {'count': '3', 'name': 'austrian'}
#
#                                               66  \
# 23557   {'count': '2', 'name': 'spanish-author'}
# 111905            {'count': '1', 'name': '2500'}
# 3769       {'count': '3', 'name': 'anthologies'}
#
#                                                       67  \
# 23557   {'count': '2', 'name': '2016-reading-challenge'}
# 111905     {'count': '1', 'name': '2015-2017-book-list'}
# 3769                  {'count': '3', 'name': 'literary'}
#
#                                                68  \
# 23557   {'count': '2', 'name': 'favourite-books'}
# 111905         {'count': '1', 'name': 'i-own-it'}
# 3769        {'count': '3', 'name': 'collections'}
#
#                                                      69  \
# 23557   {'count': '2', 'name': 'nypl-books-of-century'}
# 111905                     {'count': '1', 'name': 'pb'}
# 3769                   {'count': '3', 'name': 'own-it'}
#
#                                                   70  \
# 23557   {'count': '2', 'name': 'spanish-portuguese'}
# 111905    {'count': '1', 'name': 'written-by-women'}
# 3769                 {'count': '3', 'name': 'verse'}
#
#                                             71  \
# 23557        {'count': '2', 'name': 're-read'}
# 111905  {'count': '1', 'name': 'fabclub-2015'}
# 3769       {'count': '3', 'name': 'modernism'}
#
#                                                72  \
# 23557            {'count': '2', 'name': 'مكتبتى'}
# 111905  {'count': '1', 'name': 'fiction-general'}
# 3769            {'count': '3', 'name': '5-stars'}
#
#                                             73  \
# 23557       {'count': '2', 'name': 'le-monde'}
# 111905  {'count': '1', 'name': 'read-in-2014'}
# 3769       {'count': '3', 'name': 'anthology'}
#
#                                              74  \
# 23557   {'count': '2', 'name': 'list-le-monde'}
# 111905    {'count': '1', 'name': 'to-purchase'}
# 3769       {'count': '3', 'name': 'unfinished'}
#
#                                                 75  \
# 23557   {'count': '2', 'name': 'classics-to-read'}
# 111905      {'count': '1', 'name': 'place-canada'}
# 3769             {'count': '3', 'name': 'on-hold'}
#
#                                                        76  \
# 23557   {'count': '2', 'name': 'top-100-books-of-all-t...
# 111905             {'count': '1', 'name': 'feminist-lit'}
# 3769                {'count': '3', 'name': 'to-purchase'}
#
#                                                    77  \
# 23557   {'count': '2', 'name': 'european-literature'}
# 111905       {'count': '1', 'name': 'the-book-thing'}
# 3769                {'count': '3', 'name': 'beloved'}
#
#                                              78  \
# 23557   {'count': '2', 'name': 'mi-biblioteca'}
# 111905     {'count': '1', 'name': 'watch-list'}
# 3769        {'count': '2', 'name': 'read-2017'}
#
#                                             79  \
# 23557     {'count': '2', 'name': 'literatura'}
# 111905       {'count': '1', 'name': 'vagenda'}
# 3769    {'count': '2', 'name': 'read-in-2017'}
#
#                                                        80  \
# 23557       {'count': '2', 'name': 'norwegian-book-club'}
# 111905  {'count': '1', 'name': 'super-interesting-real...
# 3769                    {'count': '2', 'name': 'austria'}
#
#                                                   81  \
# 23557         {'count': '2', 'name': 'read-in-2014'}
# 111905  {'count': '1', 'name': 'read-pre-goodreads'}
# 3769          {'count': '2', 'name': 'the-classics'}
#
#                                                        82  \
# 23557                  {'count': '2', 'name': 'siglo-xx'}
# 111905  {'count': '1', 'name': 'i-have-an-essay-on-thi...
# 3769                     {'count': '2', 'name': 'novels'}
#
#                                                83  \
# 23557           {'count': '2', 'name': 'english'}
# 111905       {'count': '1', 'name': 'five-stars'}
# 3769    {'count': '2', 'name': 'read-for-school'}
#
#                                                    84  \
# 23557    {'count': '2', 'name': 'world-library-list'}
# 111905  {'count': '1', 'name': 'english-major-books'}
# 3769        {'count': '2', 'name': 'to-read-fiction'}
#
#                                        85                                  86  \
# 23557   {'count': '2', 'name': 'romance'}  {'count': '2', 'name': 'politics'}
# 111905   {'count': '1', 'name': 'review'}  {'count': '1', 'name': 'the-haul'}
# 3769    {'count': '2', 'name': 're-read'}     {'count': '2', 'name': 'faves'}
#
#                                                 87  \
# 23557        {'count': '2', 'name': 'owned-books'}
# 111905  {'count': '1', 'name': 'commonwealth-lit'}
# 3769          {'count': '2', 'name': 'musicmaybe'}
#
#                                                   88  \
# 23557            {'count': '2', 'name': 'not-owned'}
# 111905  {'count': '1', 'name': 'absolute-favorites'}
# 3769             {'count': '2', 'name': 'bilingual'}
#
#                                                        89  \
# 23557   {'count': '2', 'name': 'le-monde-s-100-books-o...
# 111905  {'count': '1', 'name': 'short-stories-plays-po...
# 3769            {'count': '2', 'name': 'german-language'}
#
#                                          90  \
# 23557       {'count': '2', 'name': 'poems'}
# 111905   {'count': '1', 'name': 'new-2014'}
# 3769    {'count': '2', 'name': 'abandoned'}
#
#                                                91  \
# 23557        {'count': '2', 'name': 'peninsular'}
# 111905     {'count': '1', 'name': 'on-the-radar'}
# 3769    {'count': '2', 'name': 'german-classics'}
#
#                                                        92  \
# 23557   {'count': '2', 'name': 'nypl-books-of-the-cent...
# 111905      {'count': '1', 'name': 'by-women-who-matter'}
# 3769             {'count': '2', 'name': 'favorite-books'}
#
#                                               93  \
# 23557          {'count': '2', 'name': 'espagne'}
# 111905  {'count': '1', 'name': 'female-authors'}
# 3769        {'count': '2', 'name': 'interested'}
#
#                                           94  \
# 23557   {'count': '2', 'name': 'mis-libros'}
# 111905       {'count': '1', 'name': '1900s'}
# 3769    {'count': '2', 'name': 'in-storage'}
#
#                                        95  \
# 23557   {'count': '2', 'name': 'novelas'}
# 111905   {'count': '1', 'name': 'kindle'}
# 3769    {'count': '2', 'name': '4-stars'}
#
#                                                  96  \
# 23557   {'count': '2', 'name': 'ny-public-library'}
# 111905  {'count': '1', 'name': 'kaunokirjallisuus'}
# 3769                  {'count': '2', 'name': 'lit'}
#
#                                                 97  \
# 23557   {'count': '2', 'name': 'bucket-list-book'}
# 111905        {'count': '1', 'name': 'surrealist'}
# 3769    {'count': '2', 'name': 'poetry-and-prose'}
#
#                                              98  \
# 23557          {'count': '2', 'name': 'espa-a'}
# 111905  {'count': '1', 'name': 'made-me-think'}
# 3769        {'count': '2', 'name': 'available'}
#
#                                              99
# 23557   {'count': '2', 'name': 'spanish-books'}
# 111905       {'count': '1', 'name': 'dystopia'}
# 3769     {'count': '2', 'name': 'to-read-soon'}
